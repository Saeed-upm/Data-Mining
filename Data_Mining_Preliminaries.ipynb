# %% [markdown]
# <a href="https://colab.research.google.com/github/Saeed-upm/Data-Mining/blob/main/Data_Mining_Preliminaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## مقدمات
# $\int_0^1$

# %%
type(3)
# Out:
# int

# %%
type(True)
# Out:
# bool

# %%
bool(1)
# Out:
# True

# %%
int(1.999)
# Out:
# 1

# %%
float(5)
# Out:
# 5.0

# %%
str(5.6)
# Out:
# '5.6'

# %%
int(float('3.45'))
# Out:
# 3

# %%
float('56.45')
# Out:
# 56.45

# %%
type('45.566')
# Out:
# str

# %%
x=1
print(x)
# Out:
# 1

# %%
A='Ali is the best.'

# %%
type(A)
# Out:
# str

# %%
print(len(A))
print(A[0])
print(A[-1])
print(A[::2])
print(A[0:9:2])
print(A[4:15])
# Out:
# 16
# A
# .
# Aii h et
# Aii h
# is the best

# %%
B=A.replace('best', 'worst')
print(B)
# Out:
# Ali is the worst.

# %%
B.find('worst')
# Out:
# 11

# %%
C=A.upper()
print(C)
# Out:
# ALI IS THE BEST.

# %%
type(A)
print(A)
# Out:
# Ali is the best.

# %%
def f(x,y):
  z=np.exp(x+y)
  return z

# %%
z=f(2,3)
print(z)
# Out:
# 148.4131591025766

# %%
print(np.pi)
# Out:
# 3.141592653589793

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 2*np.pi, 50)
y = np.sin(x)
z = np.cos(x)
plt.plot(x,y, label="$\sin(x)$")
plt.xlabel("x")
plt.ylabel('$\sin(x)$ and $\cos(x)$')
plt.plot(x,z, label='$\cos(x)$')
leg = plt.legend(loc='upper right')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)
z = np.cos(x)
plt.scatter(x,y, label="$\sin(x)$")
plt.xlabel("x")
plt.ylabel('$\sin(x)$ and $\cos(x)$')
plt.scatter(x,z,label='$\cos(x)$')
leg = plt.legend(loc='upper right')
plt.show()

# %%
print(x[99])
# Out:
# 6.283185307179586

# %% [markdown]
# محاسبه مقادیر شاخصهای مرکزی و پراکندگی با استفاده از بسته numpy

# %%
import numpy as np

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = np.mean(speed)
print(x)
# Out:
# 89.76923076923077

# %%
import numpy as np

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = np.median(speed)

print(x)
# Out:
# 87.0

# %%
import statistics

data = [11, 21, 11, 19, 46, 21, 19, 29, 21, 18, 3, 11, 11]

x = statistics.mean(data)
print(x)

y = statistics.median(data)
print(y)

z = statistics.mode(data)
print(z)

a = statistics.stdev(data)
print(a)

b = statistics.variance(data)
print(b)
# Out:
# 18.53846153846154
# 19
# 11
# 10.611435534486562
# 112.6025641025641

# %%
print("Q2 quantile of arr : ", np.quantile(speed, .50))
print("Q1 quantile of arr : ", np.quantile(speed, .25))
print("Q3 quantile of arr : ", np.quantile(speed, .75))
print("100th quantile of arr : ", np.quantile(speed, .1))
print("IQR = ", np.quantile(speed, .75)-np.quantile(speed, .25))
print("1.5 * IQR = ",  1.5*(np.quantile(speed, .75)-np.quantile(speed, .25)))
print("Q1-1.5 * IQR = ", np.quantile(speed, .25)-1.5*(np.quantile(speed, .75)-np.quantile(speed, .25)))
print("Q3+1.5 * IQR = ", np.quantile(speed, .75)+1.5*(np.quantile(speed, .75)-np.quantile(speed, .25)))
# Out:
# Q2 quantile of arr :  87.0
# Q1 quantile of arr :  86.0
# Q3 quantile of arr :  94.0
# 100th quantile of arr :  79.4
# IQR =  8.0
# 1.5 * IQR =  12.0
# Q1-1.5 * IQR =  74.0
# Q3+1.5 * IQR =  106.0

# %%
sort_speed=np.sort(speed)
print(sort_speed)
# Out:
# [ 77  78  85  86  86  86  87  87  88  94  99 103 111]

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.boxplot(speed)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
my_data= np.random.normal(0, 1, size=100)
plt.boxplot(my_data)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# Random test data
all_data = [np.random.normal(0, std, size=100) for std in range(1, 4)]
labels = ['x1', 'x2', 'x3']

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))

# rectangular box plot
bplot1 = ax1.boxplot(all_data,
                     vert=True,  # vertical box alignment
                     patch_artist=True,  # fill with color
                     labels=labels)  # will be used to label x-ticks
ax1.set_title('Rectangular box plot')

# notch shape box plot
bplot2 = ax2.boxplot(all_data,
                     notch=True,  # notch shape
                     vert=True,  # vertical box alignment
                     patch_artist=True,  # fill with color
                     labels=labels)  # will be used to label x-ticks
ax2.set_title('Notched box plot')

# fill with colors
colors = ['pink', 'lightblue', 'lightgreen']
for bplot in (bplot1, bplot2):
    for patch, color in zip(bplot['boxes'], colors):
        patch.set_facecolor(color)

# adding horizontal grid lines
for ax in [ax1, ax2]:
    ax.yaxis.grid(True)
    ax.set_xlabel('Three separate samples')
    ax.set_ylabel('Observed values')

plt.show()

# %% [markdown]
# ## رسم نمودار چندک-چندک

# %%
import numpy as np
unit_price = np.array([40,43,47,74,75,78,115,117,120])
count_of_items_sold = np.array([275,300,250,360,515,540,320,270,350])
total = np.array([])
for i in range(len(unit_price)):
  n = unit_price[i]*np.ones(count_of_items_sold[i])
  total = np.append(total,n)
f = np.arange(len(total))
f = (f+0.5)/len(total)
plt.scatter(f,total)
plt.show()
print(f)
# Out:
# [1.57232704e-04 4.71698113e-04 7.86163522e-04 ... 9.99213836e-01
#  9.99528302e-01 9.99842767e-01]

# %%
plt.bar(unit_price,count_of_items_sold, width = 0.8)
plt.show()

# %%
my_data= np.random.normal(0, 1, size=100000)
plt.hist(my_data, bins=100)
plt.show()
mean = np.mean(my_data)
print(mean)
# Out:
# 0.00567700835489382

# %%
plt.scatter(unit_price,count_of_items_sold)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


def randrange(n, vmin, vmax):
    """
    Helper function to make an array of random numbers having shape (n, )
    with each number distributed Uniform(vmin, vmax).
    """
    return (vmax - vmin)*np.random.rand(n) + vmin

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
for m, zlow, zhigh in [('o', -50, -25), ('^', -30, -5)]:
    xs = randrange(n, 23, 32)
    ys = randrange(n, 0, 100)
    zs = randrange(n, zlow, zhigh)
    ax.scatter(xs, ys, zs, marker=m)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

# Make data
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)
x = 10 * np.outer(np.cos(u), np.sin(v))
y = 10 * np.outer(np.sin(u), np.sin(v))
z = 10 * np.outer(np.ones(np.size(u)), np.cos(v))

# Plot the surface
ax.plot_surface(x, y, z)

# Set an equal aspect ratio
ax.set_aspect('equal')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib import cm
from matplotlib.ticker import LinearLocator

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()
